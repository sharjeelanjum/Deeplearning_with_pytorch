# %% [markdown]
# <a href="https://colab.research.google.com/github/sharjeelanjum/Deeplearning_with_pytorch/blob/main/DQN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import random
from collections import deque

class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_dim)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

class ReplayBuffer:
    def __init__(self, buffer_size):
        self.buffer = deque(maxlen=buffer_size)

    def add(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = zip(*batch)
        return state, action, reward, next_state, done

class DQNAgent:
    def __init__(self, state_dim, action_dim, buffer_size, batch_size, gamma, lr):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.buffer = ReplayBuffer(buffer_size)
        self.batch_size = batch_size
        self.gamma = gamma
        self.model = DQN(state_dim, action_dim).to(self.device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)

    def select_action(self, state, epsilon):
        if random.random() < epsilon:
            return random.randint(0, self.action_dim-1)
        else:
            state = torch.tensor(state, dtype=torch.float32).to(self.device)
            with torch.no_grad():
                q_values = self.model(state)
            action = q_values.argmax().item()
            return action

    def train(self):
        if len(self.buffer.buffer) < self.batch_size:
            return
        state, action, reward, next_state, done = self.buffer.sample(self.batch_size)
        state = torch.tensor(state, dtype=torch.float32).to(self.device)
        action = torch.tensor(action, dtype=torch.long).to(self.device)
        reward = torch.tensor(reward, dtype=torch.float32).to(self.device)
        next_state = torch.tensor(next_state, dtype=torch.float32).to(self.device)
        done = torch.tensor(done, dtype=torch.float32).to(self.device)

        q_values = self.model(state).gather(1, action.unsqueeze(1)).squeeze(1)
        next_q_values = self.model(next_state).max(1)[0]
        expected_q_values = reward + self.gamma * next_q_values * (1 - done)
        loss = F.mse_loss(q_values, expected_q_values.detach())

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def add_to_buffer(self, state, action, reward, next_state, done):
        self.buffer.add(state, action, reward, next_state, done)

# %%
import random

class SimpleGame:
    def __init__(self):
        self.state_dim = 4
        self.action_dim = 2
        self.position = 0
        self.velocity = 0
        self.target_position = random.randint(1, 10)
        self.done = False

    def reset(self):
        self.position = 0
        self.velocity = 0
        self.target_position = random.randint(1, 10)
        self.done = False
        return self._get_state()

    def step(self, action):
        if action == 0:
            self.velocity -= 1
        elif action == 1:
            self.velocity += 1
        else:
            raise ValueError("Invalid action")

        self.velocity = max(min(self.velocity, 5), -5)
        self.position += self.velocity

        if self.position == self.target_position:
            reward = 1
            self.done = True
        elif abs(self.position - self.target_position) <= 2:
            reward = -0.1
        else:
            reward = 0

        if self.position < 0:
            self.position = 0
            self.velocity = 0
        elif self.position > 10:
            self.position = 10
            self.velocity = 0

        return self._get_state(), reward, self.done

    def _get_state(self):
        return [self.position, self.velocity, self.target_position, int(self.done)]

# %% [markdown]
# Various kinds of environments can be utilized but here I am using the simple 1D game where the agent must move to a target position.
#
# The state consists of the agent's current position, velocity, target position, and a flag for game-over. The agent can either accelerate or decelerate. If the agent reaches the target position, it gets a reward of 1 and the game ends. A penalty of -0.1 is given if the agent gets close to the target position, and going out of bounds resets the agent's position to the nearest boundary. The game is an example of a continuous control problem where the agent must control its velocity to reach the target position.

# %%
env = SimpleGame()
agent = DQNAgent(state_dim=env.state_dim, action_dim=env.action_dim, buffer_size=10000, batch_size=32, gamma=0.99, lr=0.001)

for episode in range(1000):
    state = env.reset()
    total_reward = 0
    done = False

    while not done:
        action = agent.select_action(state, epsilon=0.1)
        next_state, reward, done = env.step(action)
        agent.add_to_buffer(state, action, reward, next_state, done)
        agent.train()
        state = next_state
        total_reward += reward

    print(f"Episode {episode}: Total reward = {total_reward}")
    # Save final model weights
torch.save(agent.model.state_dict(), 'trained_model.pt')
# Out:
# Episode 0: Total reward = -0.8000000000000005
# Episode 1: Total reward = 0.6
# Episode 2: Total reward = -8.099999999999984
# Episode 3: Total reward = 0.6
# Episode 4: Total reward = 0.9
# Episode 5: Total reward = -2.800000000000002
# Episode 6: Total reward = 0.5
# Episode 7: Total reward = 0.9
# Episode 8: Total reward = 0.9
# Episode 9: Total reward = -2.2000000000000015
# Episode 10: Total reward = 0.9
# Episode 11: Total reward = -3.6999999999999993
# Episode 12: Total reward = 0.8
# Episode 13: Total reward = 0.6
# Episode 14: Total reward = 0.9
# Episode 15: Total reward = -2.700000000000002
# Episode 16: Total reward = 0.5
# Episode 17: Total reward = 1
# Episode 18: Total reward = 0.9
# Episode 19: Total reward = 0.30000000000000004
# Episode 20: Total reward = 1
# Episode 21: Total reward = -2.800000000000002
# Episode 22: Total reward = -4.899999999999995
# Episode 23: Total reward = 0.9
# Episode 24: Total reward = -18.900000000000013
# Episode 25: Total reward = -1.4000000000000008
# Episode 26: Total reward = 0.20000000000000007
# Episode 27: Total reward = -2.800000000000002
# Episode 28: Total reward = -1.2000000000000006
# Episode 29: Total reward = 1
# Episode 30: Total reward = -2.1000000000000014
# Episode 31: Total reward = -3.6999999999999993
# Episode 32: Total reward = 1
# Episode 33: Total reward = 0.30000000000000004
# Episode 34: Total reward = 1
# Episode 35: Total reward = -0.7000000000000004
# Episode 36: Total reward = -0.6000000000000003
# Episode 37: Total reward = 1.1102230246251565e-16
# Episode 38: Total reward = 0.30000000000000004
# Episode 39: Total reward = 0.7
# Episode 40: Total reward = 0.9
# Episode 41: Total reward = 1
# Episode 42: Total reward = 0.5
# Episode 43: Total reward = 0.8
# Episode 44: Total reward = -10.699999999999974
# Episode 45: Total reward = -4.299999999999997
# Episode 46: Total reward = 1.1102230246251565e-16
# Episode 47: Total reward = 0.4
# Episode 48: Total reward = 1
# Episode 49: Total reward = -4.799999999999995
# Episode 50: Total reward = 0.9
# Episode 51: Total reward = 0.8
# Episode 52: Total reward = 0.8
# Episode 53: Total reward = 0.4
# Episode 54: Total reward = 0.9
# Episode 55: Total reward = -1.5000000000000009
# Episode 56: Total reward = 1
# Episode 57: Total reward = -3.8999999999999986
# Episode 58: Total reward = 0.9
# Episode 59: Total reward = 0.10000000000000009
# Episode 60: Total reward = 0.7
# Episode 61: Total reward = -8.499999999999982
# Episode 62: Total reward = 0.8
# Episode 63: Total reward = -4.4999999999999964
# Episode 64: Total reward = -3.4000000000000004
# Episode 65: Total reward = 1
# Episode 66: Total reward = 1
# Episode 67: Total reward = -1.600000000000001
# Episode 68: Total reward = 1
# Episode 69: Total reward = 1
# Episode 70: Total reward = -0.30000000000000004
# Episode 71: Total reward = 1
# Episode 72: Total reward = 1
# Episode 73: Total reward = -5.799999999999992
# Episode 74: Total reward = -5.699999999999992
# Episode 75: Total reward = -2.1000000000000014
# Episode 76: Total reward = -1.3000000000000007
# Episode 77: Total reward = 0.8
# Episode 78: Total reward = 0.9
# Episode 79: Total reward = 0.9
# Episode 80: Total reward = 0.9
# Episode 81: Total reward = 0.5
# Episode 82: Total reward = 0.10000000000000009
# Episode 83: Total reward = -1.1000000000000005
# Episode 84: Total reward = -0.9000000000000006
# Episode 85: Total reward = 0.9
# Episode 86: Total reward = -1.4000000000000008
# Episode 87: Total reward = 0.9
# Episode 88: Total reward = 0.9
# Episode 89: Total reward = 0.9
# Episode 90: Total reward = -0.8000000000000005
# Episode 91: Total reward = 0.9
# Episode 92: Total reward = -13.999999999999963
# Episode 93: Total reward = -1.1000000000000005
# Episode 94: Total reward = 0.8
# Episode 95: Total reward = 1
# Episode 96: Total reward = -0.9000000000000006
# Episode 97: Total reward = -4.699999999999996
# Episode 98: Total reward = 0.9
# Episode 99: Total reward = -14.69999999999996
# Episode 100: Total reward = 0.6
# Episode 101: Total reward = 0.7
# Episode 102: Total reward = -1.2000000000000006
# Episode 103: Total reward = 0.8
# Episode 104: Total reward = 0.7
# Episode 105: Total reward = 0.8
# Episode 106: Total reward = -1.9000000000000012
# Episode 107: Total reward = 0.30000000000000004
# Episode 108: Total reward = 1
# Episode 109: Total reward = -3.5999999999999996
# Episode 110: Total reward = -1.9000000000000012
# Episode 111: Total reward = -3.200000000000001
# Episode 112: Total reward = -4.299999999999997
# Episode 113: Total reward = -1.2000000000000006
# Episode 114: Total reward = 0.4
# Episode 115: Total reward = 1
# Episode 116: Total reward = 1
# Episode 117: Total reward = -0.40000000000000013
# Episode 118: Total reward = -0.8000000000000005
# Episode 119: Total reward = 1
# Episode 120: Total reward = 1.1102230246251565e-16
# Episode 121: Total reward = 0.9
# Episode 122: Total reward = -2.3000000000000016
# Episode 123: Total reward = 0.9
# Episode 124: Total reward = 0.6
# Episode 125: Total reward = -13.199999999999966
# Episode 126: Total reward = 0.8
# Episode 127: Total reward = 0.6
# Episode 128: Total reward = 0.6
# Episode 129: Total reward = -1.600000000000001
# Episode 130: Total reward = 0.6
# Episode 131: Total reward = 0.6
# Episode 132: Total reward = 0.10000000000000009
# Episode 133: Total reward = 0.9
# Episode 134: Total reward = 0.10000000000000009
# Episode 135: Total reward = -1.3000000000000007
# Episode 136: Total reward = 0.4
# Episode 137: Total reward = 0.7
# Episode 138: Total reward = -1.3000000000000007
# Episode 139: Total reward = 0.7
# Episode 140: Total reward = -0.40000000000000013
# Episode 141: Total reward = 0.9
# Episode 142: Total reward = -1.2000000000000006
# Episode 143: Total reward = -1.3000000000000007
# Episode 144: Total reward = 1
# Episode 145: Total reward = -1.8000000000000012
# Episode 146: Total reward = 0.5
# Episode 147: Total reward = 0.9
# Episode 148: Total reward = 0.30000000000000004
# Episode 149: Total reward = -3.0000000000000018
# Episode 150: Total reward = -0.09999999999999987
# Episode 151: Total reward = 0.30000000000000004
# Episode 152: Total reward = -0.40000000000000013
# Episode 153: Total reward = 1.1102230246251565e-16
# Episode 154: Total reward = 0.5
# Episode 155: Total reward = 0.9
# Episode 156: Total reward = 0.8
# Episode 157: Total reward = -1.1000000000000005
# Episode 158: Total reward = -1.0000000000000004
# Episode 159: Total reward = 0.8
# Episode 160: Total reward = -0.9000000000000006
# Episode 161: Total reward = 0.8
# Episode 162: Total reward = 0.8
# Episode 163: Total reward = -0.6000000000000003
# Episode 164: Total reward = 0.7
# Episode 165: Total reward = -0.09999999999999987
# Episode 166: Total reward = -3.0000000000000018
# Episode 167: Total reward = 1
# Episode 168: Total reward = -0.9000000000000006
# Episode 169: Total reward = 1
# Episode 170: Total reward = 0.20000000000000007
# Episode 171: Total reward = 0.9
# Episode 172: Total reward = -1.8000000000000012
# Episode 173: Total reward = 0.5
# Episode 174: Total reward = 1.1102230246251565e-16
# Episode 175: Total reward = 0.7
# Episode 176: Total reward = 0.9
# Episode 177: Total reward = 0.9
# Episode 178: Total reward = 0.9
# Episode 179: Total reward = 0.20000000000000007
# Episode 180: Total reward = -1.9000000000000012
# Episode 181: Total reward = -7.599999999999985
# Episode 182: Total reward = 0.30000000000000004
# Episode 183: Total reward = 0.9
# Episode 184: Total reward = 1.1102230246251565e-16
# Episode 185: Total reward = -4.599999999999996
# Episode 186: Total reward = 0.30000000000000004
# Episode 187: Total reward = 0.9
# Episode 188: Total reward = 1
# Episode 189: Total reward = -0.30000000000000004
# Episode 190: Total reward = 0.5
# Episode 191: Total reward = 0.5
# Episode 192: Total reward = 0.9
# Episode 193: Total reward = 1
# Episode 194: Total reward = -0.09999999999999987
# Episode 195: Total reward = 0.5
# Episode 196: Total reward = 0.20000000000000007
# Episode 197: Total reward = 0.9
# Episode 198: Total reward = 1
# Episode 199: Total reward = 1
# Episode 200: Total reward = 0.10000000000000009
# Episode 201: Total reward = 0.9
# Episode 202: Total reward = 0.9
# Episode 203: Total reward = 0.7
# Episode 204: Total reward = 0.9
# Episode 205: Total reward = 0.9
# Episode 206: Total reward = 0.4
# Episode 207: Total reward = -2.900000000000002
# Episode 208: Total reward = -0.40000000000000013
# Episode 209: Total reward = 0.20000000000000007
# Episode 210: Total reward = -0.40000000000000013
# Episode 211: Total reward = -1.0000000000000004
# Episode 212: Total reward = 1
# Episode 213: Total reward = 0.9
# Episode 214: Total reward = 1
# Episode 215: Total reward = 0.9
# Episode 216: Total reward = -6.29999999999999
# Episode 217: Total reward = -2.2000000000000015
# Episode 218: Total reward = 0.9
# Episode 219: Total reward = 0.7
# Episode 220: Total reward = 0.4
# Episode 221: Total reward = -1.1000000000000005
# Episode 222: Total reward = 0.9
# Episode 223: Total reward = 0.6
# Episode 224: Total reward = -1.9000000000000012
# Episode 225: Total reward = -2.800000000000002
# Episode 226: Total reward = 0.9
# Episode 227: Total reward = -0.9000000000000006
# Episode 228: Total reward = 0.8
# Episode 229: Total reward = 0.5
# Episode 230: Total reward = -3.799999999999999
# Episode 231: Total reward = 0.30000000000000004
# Episode 232: Total reward = 0.5
# Episode 233: Total reward = 0.9
# Episode 234: Total reward = -8.199999999999983
# Episode 235: Total reward = -13.299999999999965
# Episode 236: Total reward = 0.4
# Episode 237: Total reward = 0.6
# Episode 238: Total reward = 0.9
# Episode 239: Total reward = -4.399999999999997
# Episode 240: Total reward = -0.8000000000000005
# Episode 241: Total reward = -0.9000000000000006
# Episode 242: Total reward = -2.5000000000000018
# Episode 243: Total reward = 0.9
# Episode 244: Total reward = -0.8000000000000005
# Episode 245: Total reward = 0.9
# Episode 246: Total reward = 1
# Episode 247: Total reward = 0.9
# Episode 248: Total reward = 1
# Episode 249: Total reward = 1
# Episode 250: Total reward = -0.09999999999999987
# Episode 251: Total reward = 1
# Episode 252: Total reward = -1.700000000000001
# Episode 253: Total reward = 0.9
# Episode 254: Total reward = 0.9
# Episode 255: Total reward = -1.1000000000000005
# Episode 256: Total reward = -2.600000000000002
# Episode 257: Total reward = -0.6000000000000003
# Episode 258: Total reward = 0.5
# Episode 259: Total reward = -0.9000000000000006
# Episode 260: Total reward = 0.5
# Episode 261: Total reward = -0.8000000000000005
# Episode 262: Total reward = -1.1000000000000005
# Episode 263: Total reward = -2.5000000000000018
# Episode 264: Total reward = 0.6
# Episode 265: Total reward = 0.7
# Episode 266: Total reward = 1
# Episode 267: Total reward = -0.09999999999999987
# Episode 268: Total reward = -0.8000000000000005
# Episode 269: Total reward = -0.09999999999999987
# Episode 270: Total reward = 1.1102230246251565e-16
# Episode 271: Total reward = 1
# Episode 272: Total reward = 0.9
# Episode 273: Total reward = -5.299999999999994
# Episode 274: Total reward = 1
# Episode 275: Total reward = 0.5
# Episode 276: Total reward = 0.6
# Episode 277: Total reward = -0.40000000000000013
# Episode 278: Total reward = 0.9
# Episode 279: Total reward = 0.7
# Episode 280: Total reward = 1
# Episode 281: Total reward = 0.4
# Episode 282: Total reward = 0.10000000000000009
# Episode 283: Total reward = -0.09999999999999987
# Episode 284: Total reward = -2.0000000000000013
# Episode 285: Total reward = 1
# Episode 286: Total reward = -0.5000000000000002
# Episode 287: Total reward = -0.09999999999999987
# Episode 288: Total reward = 0.7
# Episode 289: Total reward = 1.1102230246251565e-16
# Episode 290: Total reward = 1
# Episode 291: Total reward = 1
# Episode 292: Total reward = 0.5
# Episode 293: Total reward = -0.30000000000000004
# Episode 294: Total reward = 0.8
# Episode 295: Total reward = -0.6000000000000003
# Episode 296: Total reward = 0.6
# Episode 297: Total reward = -2.3000000000000016
# Episode 298: Total reward = 0.6
# Episode 299: Total reward = -0.8000000000000005
# Episode 300: Total reward = -0.6000000000000003
# Episode 301: Total reward = 1
# Episode 302: Total reward = 0.5
# Episode 303: Total reward = 0.6
# Episode 304: Total reward = 1
# Episode 305: Total reward = 0.8
# Episode 306: Total reward = 1
# Episode 307: Total reward = 0.5
# Episode 308: Total reward = -0.30000000000000004
# Episode 309: Total reward = -0.19999999999999996
# Episode 310: Total reward = 0.9
# Episode 311: Total reward = -1.2000000000000006
# Episode 312: Total reward = 0.6
# Episode 313: Total reward = 0.9
# Episode 314: Total reward = 1
# Episode 315: Total reward = 0.9
# Episode 316: Total reward = -0.19999999999999996
# Episode 317: Total reward = -1.8000000000000012
# Episode 318: Total reward = 0.9
# Episode 319: Total reward = 0.10000000000000009
# Episode 320: Total reward = -2.3000000000000016
# Episode 321: Total reward = -5.699999999999992
# Episode 322: Total reward = -0.6000000000000003
# Episode 323: Total reward = 1
# Episode 324: Total reward = -2.700000000000002
# Episode 325: Total reward = 1
# Episode 326: Total reward = 1
# Episode 327: Total reward = -0.6000000000000003
# Episode 328: Total reward = -5.499999999999993
# Episode 329: Total reward = 1
# Episode 330: Total reward = 1
# Episode 331: Total reward = -1.3000000000000007
# Episode 332: Total reward = 0.9
# Episode 333: Total reward = -0.7000000000000004
# Episode 334: Total reward = 0.10000000000000009
# Episode 335: Total reward = 0.10000000000000009
# Episode 336: Total reward = -1.600000000000001
# Episode 337: Total reward = -1.600000000000001
# Episode 338: Total reward = 0.4
# Episode 339: Total reward = 0.9
# Episode 340: Total reward = 0.9
# Episode 341: Total reward = 0.20000000000000007
# Episode 342: Total reward = -0.5000000000000002
# Episode 343: Total reward = 1
# Episode 344: Total reward = -1.2000000000000006
# Episode 345: Total reward = -0.7000000000000004
# Episode 346: Total reward = 0.9
# Episode 347: Total reward = -8.599999999999982
# Episode 348: Total reward = 0.9
# Episode 349: Total reward = 0.7
# Episode 350: Total reward = -5.299999999999994
# Episode 351: Total reward = 0.8
# Episode 352: Total reward = -1.2000000000000006
# Episode 353: Total reward = 0.7
# Episode 354: Total reward = -0.30000000000000004
# Episode 355: Total reward = 1
# Episode 356: Total reward = -6.39999999999999
# Episode 357: Total reward = -1.8000000000000012
# Episode 358: Total reward = -0.40000000000000013
# Episode 359: Total reward = -6.599999999999989
# Episode 360: Total reward = -6.39999999999999
# Episode 361: Total reward = -1.8000000000000012
# Episode 362: Total reward = -19.50000000000002
# Episode 363: Total reward = 1
# Episode 364: Total reward = 0.30000000000000004
# Episode 365: Total reward = -2.600000000000002
# Episode 366: Total reward = -6.099999999999991
# Episode 367: Total reward = 0.6
# Episode 368: Total reward = 0.8
# Episode 369: Total reward = 1
# Episode 370: Total reward = -0.7000000000000004
# Episode 371: Total reward = -0.6000000000000003
# Episode 372: Total reward = -0.19999999999999996
# Episode 373: Total reward = 0.7
# Episode 374: Total reward = -1.5000000000000009
# Episode 375: Total reward = 0.9
# Episode 376: Total reward = -6.099999999999991
# Episode 377: Total reward = 0.9
# Episode 378: Total reward = 0.7
# Episode 379: Total reward = -4.899999999999995
# Episode 380: Total reward = 0.10000000000000009
# Episode 381: Total reward = 0.7
# Episode 382: Total reward = 0.9
# Episode 383: Total reward = 0.5
# Episode 384: Total reward = 0.30000000000000004
# Episode 385: Total reward = -1.5000000000000009
# Episode 386: Total reward = 0.30000000000000004
# Episode 387: Total reward = -1.5000000000000009
# Episode 388: Total reward = 0.9
# Episode 389: Total reward = 0.9
# Episode 390: Total reward = -0.30000000000000004
# Episode 391: Total reward = 0.7
# Episode 392: Total reward = -0.30000000000000004
# Episode 393: Total reward = -0.09999999999999987
# Episode 394: Total reward = -0.40000000000000013
# Episode 395: Total reward = 0.7
# Episode 396: Total reward = 0.4
# Episode 397: Total reward = -1.2000000000000006
# Episode 398: Total reward = -0.19999999999999996
# Episode 399: Total reward = -2.4000000000000017
# Episode 400: Total reward = 0.9
# Episode 401: Total reward = -1.2000000000000006
# Episode 402: Total reward = 0.9
# Episode 403: Total reward = 0.5
# Episode 404: Total reward = -3.799999999999999
# Episode 405: Total reward = 0.30000000000000004
# Episode 406: Total reward = -2.900000000000002
# Episode 407: Total reward = -1.4000000000000008
# Episode 408: Total reward = -1.2000000000000006
# Episode 409: Total reward = -0.5000000000000002
# Episode 410: Total reward = 0.7
# Episode 411: Total reward = -0.09999999999999987
# Episode 412: Total reward = -0.09999999999999987
# Episode 413: Total reward = 0.9
# Episode 414: Total reward = 0.9
# Episode 415: Total reward = 0.9
# Episode 416: Total reward = 0.4
# Episode 417: Total reward = 0.9
# Episode 418: Total reward = 0.6
# Episode 419: Total reward = 0.4
# Episode 420: Total reward = 0.20000000000000007
# Episode 421: Total reward = 0.4
# Episode 422: Total reward = -1.3000000000000007
# Episode 423: Total reward = 0.30000000000000004
# Episode 424: Total reward = 1
# Episode 425: Total reward = -0.9000000000000006
# Episode 426: Total reward = 0.5
# Episode 427: Total reward = -11.299999999999972
# Episode 428: Total reward = 0.10000000000000009
# Episode 429: Total reward = -1.9000000000000012
# Episode 430: Total reward = 0.9
# Episode 431: Total reward = -3.8999999999999986
# Episode 432: Total reward = 0.7
# Episode 433: Total reward = 0.10000000000000009
# Episode 434: Total reward = -2.5000000000000018
# Episode 435: Total reward = 1
# Episode 436: Total reward = 0.9
# Episode 437: Total reward = -0.30000000000000004
# Episode 438: Total reward = -2.4000000000000017
# Episode 439: Total reward = -1.2000000000000006
# Episode 440: Total reward = 0.9
# Episode 441: Total reward = -0.09999999999999987
# Episode 442: Total reward = 0.9
# Episode 443: Total reward = -0.5000000000000002
# Episode 444: Total reward = -2.600000000000002
# Episode 445: Total reward = 1
# Episode 446: Total reward = -2.800000000000002
# Episode 447: Total reward = 0.6
# Episode 448: Total reward = 0.9
# Episode 449: Total reward = -0.19999999999999996
# Episode 450: Total reward = 0.9
# Episode 451: Total reward = 0.9
# Episode 452: Total reward = -4.999999999999995
# Episode 453: Total reward = -0.5000000000000002
# Episode 454: Total reward = 0.6
# Episode 455: Total reward = 1
# Episode 456: Total reward = 0.9
# Episode 457: Total reward = 0.9
# Episode 458: Total reward = -0.19999999999999996
# Episode 459: Total reward = -0.5000000000000002
# Episode 460: Total reward = -1.3000000000000007
# Episode 461: Total reward = 0.9
# Episode 462: Total reward = -0.7000000000000004
# Episode 463: Total reward = 0.9
# Episode 464: Total reward = 1
# Episode 465: Total reward = 0.6
# Episode 466: Total reward = -0.7000000000000004
# Episode 467: Total reward = -5.299999999999994
# Episode 468: Total reward = -2.5000000000000018
# Episode 469: Total reward = 0.5
# Episode 470: Total reward = -0.5000000000000002
# Episode 471: Total reward = -5.8999999999999915
# Episode 472: Total reward = 1
# Episode 473: Total reward = 0.9
# Episode 474: Total reward = -7.399999999999986
# Episode 475: Total reward = 0.7
# Episode 476: Total reward = 0.7
# Episode 477: Total reward = 0.9
# Episode 478: Total reward = 0.30000000000000004
# Episode 479: Total reward = 0.8
# Episode 480: Total reward = -0.5000000000000002
# Episode 481: Total reward = 0.9
# Episode 482: Total reward = 0.9
# Episode 483: Total reward = -0.30000000000000004
# Episode 484: Total reward = 0.9
# Episode 485: Total reward = 1
# Episode 486: Total reward = 0.6
# Episode 487: Total reward = 0.7
# Episode 488: Total reward = -0.30000000000000004
# Episode 489: Total reward = 1
# Episode 490: Total reward = -3.5
# Episode 491: Total reward = 0.6
# Episode 492: Total reward = -0.40000000000000013
# Episode 493: Total reward = 0.9
# Episode 494: Total reward = 0.6
# Episode 495: Total reward = 1
# Episode 496: Total reward = -0.09999999999999987
# Episode 497: Total reward = 0.4
# Episode 498: Total reward = 1
# Episode 499: Total reward = 0.8
# Episode 500: Total reward = 1.1102230246251565e-16
# Episode 501: Total reward = -1.4000000000000008
# Episode 502: Total reward = 0.9
# Episode 503: Total reward = -1.4000000000000008
# Episode 504: Total reward = -3.5
# Episode 505: Total reward = -3.6999999999999993
# Episode 506: Total reward = -1.2000000000000006
# Episode 507: Total reward = 1
# Episode 508: Total reward = 0.9
# Episode 509: Total reward = 0.9
# Episode 510: Total reward = 0.7
# Episode 511: Total reward = 0.4
# Episode 512: Total reward = 0.9
# Episode 513: Total reward = 0.4
# Episode 514: Total reward = -0.6000000000000003
# Episode 515: Total reward = 0.5
# Episode 516: Total reward = 0.4
# Episode 517: Total reward = 0.9
# Episode 518: Total reward = 0.5
# Episode 519: Total reward = 0.30000000000000004
# Episode 520: Total reward = -1.4000000000000008
# Episode 521: Total reward = -2.700000000000002
# Episode 522: Total reward = 0.20000000000000007
# Episode 523: Total reward = 0.7
# Episode 524: Total reward = 0.20000000000000007
# Episode 525: Total reward = 0.5
# Episode 526: Total reward = 0.10000000000000009
# Episode 527: Total reward = -0.6000000000000003
# Episode 528: Total reward = 0.5
# Episode 529: Total reward = -0.6000000000000003
# Episode 530: Total reward = 0.7
# Episode 531: Total reward = 0.10000000000000009
# Episode 532: Total reward = -0.30000000000000004
# Episode 533: Total reward = 0.7
# Episode 534: Total reward = -0.19999999999999996
# Episode 535: Total reward = -1.1000000000000005
# Episode 536: Total reward = -0.09999999999999987
# Episode 537: Total reward = 0.9
# Episode 538: Total reward = -0.9000000000000006
# Episode 539: Total reward = -1.9000000000000012
# Episode 540: Total reward = 0.6
# Episode 541: Total reward = 0.4
# Episode 542: Total reward = 0.10000000000000009
# Episode 543: Total reward = 0.9
# Episode 544: Total reward = 0.9
# Episode 545: Total reward = 0.5
# Episode 546: Total reward = 1
# Episode 547: Total reward = -2.0000000000000013
# Episode 548: Total reward = 0.8
# Episode 549: Total reward = 0.4
# Episode 550: Total reward = -0.30000000000000004
# Episode 551: Total reward = 1
# Episode 552: Total reward = -6.599999999999989
# Episode 553: Total reward = 0.9
# Episode 554: Total reward = 0.9
# Episode 555: Total reward = 1
# Episode 556: Total reward = 0.7
# Episode 557: Total reward = -0.09999999999999987
# Episode 558: Total reward = -4.699999999999996
# Episode 559: Total reward = 0.30000000000000004
# Episode 560: Total reward = -0.9000000000000006
# Episode 561: Total reward = 0.5
# Episode 562: Total reward = 1
# Episode 563: Total reward = -0.6000000000000003
# Episode 564: Total reward = -1.4000000000000008
# Episode 565: Total reward = 1
# Episode 566: Total reward = 1
# Episode 567: Total reward = 0.9
# Episode 568: Total reward = 0.7
# Episode 569: Total reward = 0.5
# Episode 570: Total reward = 0.5
# Episode 571: Total reward = 0.7
# Episode 572: Total reward = 0.4
# Episode 573: Total reward = -0.30000000000000004
# Episode 574: Total reward = -5.5999999999999925
# Episode 575: Total reward = 0.9
# Episode 576: Total reward = -0.6000000000000003
# Episode 577: Total reward = -0.09999999999999987
# Episode 578: Total reward = -4.299999999999997
# Episode 579: Total reward = -0.6000000000000003
# Episode 580: Total reward = 0.7
# Episode 581: Total reward = 0.20000000000000007
# Episode 582: Total reward = 0.9
# Episode 583: Total reward = 0.7
# Episode 584: Total reward = 1.1102230246251565e-16
# Episode 585: Total reward = 1
# Episode 586: Total reward = 0.7
# Episode 587: Total reward = 0.9
# Episode 588: Total reward = 0.9
# Episode 589: Total reward = 0.6
# Episode 590: Total reward = -2.1000000000000014
# Episode 591: Total reward = 1
# Episode 592: Total reward = 0.7
# Episode 593: Total reward = 0.4
# Episode 594: Total reward = 1
# Episode 595: Total reward = -3.200000000000001
# Episode 596: Total reward = 0.9
# Episode 597: Total reward = -2.700000000000002
# Episode 598: Total reward = 1
# Episode 599: Total reward = 1
# Episode 600: Total reward = -6.899999999999988
# Episode 601: Total reward = 0.9
# Episode 602: Total reward = 1
# Episode 603: Total reward = 1
# Episode 604: Total reward = 1
# Episode 605: Total reward = 0.5
# Episode 606: Total reward = 0.8
# Episode 607: Total reward = -1.5000000000000009
# Episode 608: Total reward = 0.9
# Episode 609: Total reward = 0.8
# Episode 610: Total reward = 0.8
# Episode 611: Total reward = 0.4
# Episode 612: Total reward = 1
# Episode 613: Total reward = 0.8
# Episode 614: Total reward = 0.9
# Episode 615: Total reward = -7.2999999999999865
# Episode 616: Total reward = -2.4000000000000017
# Episode 617: Total reward = 0.9
# Episode 618: Total reward = 0.5
# Episode 619: Total reward = 0.9
# Episode 620: Total reward = 0.9
# Episode 621: Total reward = -0.30000000000000004
# Episode 622: Total reward = 0.9
# Episode 623: Total reward = 0.7
# Episode 624: Total reward = 0.8
# Episode 625: Total reward = 0.20000000000000007
# Episode 626: Total reward = 0.7
# Episode 627: Total reward = 0.9
# Episode 628: Total reward = 0.8
# Episode 629: Total reward = 0.9
# Episode 630: Total reward = 0.9
# Episode 631: Total reward = 0.8
# Episode 632: Total reward = 0.8
# Episode 633: Total reward = -4.1999999999999975
# Episode 634: Total reward = -0.9000000000000006
# Episode 635: Total reward = -0.6000000000000003
# Episode 636: Total reward = -1.9000000000000012
# Episode 637: Total reward = 0.6
# Episode 638: Total reward = 0.9
# Episode 639: Total reward = 0.5
# Episode 640: Total reward = 1
# Episode 641: Total reward = -6.099999999999991
# Episode 642: Total reward = -2.800000000000002
# Episode 643: Total reward = -0.7000000000000004
# Episode 644: Total reward = -3.0000000000000018
# Episode 645: Total reward = 1
# Episode 646: Total reward = -7.999999999999984
# Episode 647: Total reward = -0.40000000000000013
# Episode 648: Total reward = 1
# Episode 649: Total reward = 0.30000000000000004
# Episode 650: Total reward = 1
# Episode 651: Total reward = -4.299999999999997
# Episode 652: Total reward = -1.0000000000000004
# Episode 653: Total reward = -0.8000000000000005
# Episode 654: Total reward = -4.799999999999995
# Episode 655: Total reward = 0.8
# Episode 656: Total reward = 0.20000000000000007
# Episode 657: Total reward = -6.099999999999991
# Episode 658: Total reward = 1
# Episode 659: Total reward = 1
# Episode 660: Total reward = 0.6
# Episode 661: Total reward = -0.5000000000000002
# Episode 662: Total reward = 1
# Episode 663: Total reward = -3.9999999999999982
# Episode 664: Total reward = 0.9
# Episode 665: Total reward = -5.199999999999994
# Episode 666: Total reward = 1.1102230246251565e-16
# Episode 667: Total reward = -1.1000000000000005
# Episode 668: Total reward = 1
# Episode 669: Total reward = 0.10000000000000009
# Episode 670: Total reward = -1.2000000000000006
# Episode 671: Total reward = -1.600000000000001
# Episode 672: Total reward = 1
# Episode 673: Total reward = 1
# Episode 674: Total reward = 1
# Episode 675: Total reward = 1
# Episode 676: Total reward = 1
# Episode 677: Total reward = 0.7
# Episode 678: Total reward = -3.6999999999999993
# Episode 679: Total reward = 0.9
# Episode 680: Total reward = -0.9000000000000006
# Episode 681: Total reward = 1
# Episode 682: Total reward = 0.9
# Episode 683: Total reward = -0.09999999999999987
# Episode 684: Total reward = 0.7
# Episode 685: Total reward = 0.5
# Episode 686: Total reward = -1.5000000000000009
# Episode 687: Total reward = -3.4000000000000004
# Episode 688: Total reward = -11.69999999999997
# Episode 689: Total reward = -14.59999999999996
# Episode 690: Total reward = 0.10000000000000009
# Episode 691: Total reward = -2.700000000000002
# Episode 692: Total reward = 0.7
# Episode 693: Total reward = 1
# Episode 694: Total reward = -0.09999999999999987
# Episode 695: Total reward = 1
# Episode 696: Total reward = 1
# Episode 697: Total reward = 0.30000000000000004
# Episode 698: Total reward = 1
# Episode 699: Total reward = 0.8
# Episode 700: Total reward = 0.9
# Episode 701: Total reward = 1
# Episode 702: Total reward = -0.6000000000000003
# Episode 703: Total reward = 0.20000000000000007
# Episode 704: Total reward = -0.5000000000000002
# Episode 705: Total reward = -0.09999999999999987
# Episode 706: Total reward = 0.7
# Episode 707: Total reward = 0.10000000000000009
# Episode 708: Total reward = 0.6
# Episode 709: Total reward = 0.9
# Episode 710: Total reward = 0.6
# Episode 711: Total reward = 0.4
# Episode 712: Total reward = -0.19999999999999996
# Episode 713: Total reward = 0.6
# Episode 714: Total reward = -1.5000000000000009
# Episode 715: Total reward = 0.30000000000000004
# Episode 716: Total reward = -1.700000000000001
# Episode 717: Total reward = 1
# Episode 718: Total reward = 1
# Episode 719: Total reward = 0.5
# Episode 720: Total reward = -8.399999999999983
# Episode 721: Total reward = 0.10000000000000009
# Episode 722: Total reward = 0.8
# Episode 723: Total reward = -0.30000000000000004
# Episode 724: Total reward = 0.9
# Episode 725: Total reward = 0.7
# Episode 726: Total reward = 0.30000000000000004
# Episode 727: Total reward = 0.9
# Episode 728: Total reward = -2.2000000000000015
# Episode 729: Total reward = 0.10000000000000009
# Episode 730: Total reward = 0.9
# Episode 731: Total reward = -2.3000000000000016
# Episode 732: Total reward = 0.4
# Episode 733: Total reward = -2.800000000000002
# Episode 734: Total reward = 1
# Episode 735: Total reward = -23.800000000000082
# Episode 736: Total reward = -12.199999999999969
# Episode 737: Total reward = 1
# Episode 738: Total reward = 0.6
# Episode 739: Total reward = 0.30000000000000004
# Episode 740: Total reward = -0.7000000000000004
# Episode 741: Total reward = -7.999999999999984
# Episode 742: Total reward = -0.19999999999999996
# Episode 743: Total reward = 0.7
# Episode 744: Total reward = 0.7
# Episode 745: Total reward = 0.9
# Episode 746: Total reward = 1
# Episode 747: Total reward = -2.0000000000000013
# Episode 748: Total reward = -8.799999999999981
# Episode 749: Total reward = 0.20000000000000007
# Episode 750: Total reward = 0.6
# Episode 751: Total reward = -23.300000000000075
# Episode 752: Total reward = -1.3000000000000007
# Episode 753: Total reward = 0.30000000000000004
# Episode 754: Total reward = 0.7
# Episode 755: Total reward = 0.10000000000000009
# Episode 756: Total reward = 0.5
# Episode 757: Total reward = -0.6000000000000003
# Episode 758: Total reward = -3.4000000000000004
# Episode 759: Total reward = 0.6
# Episode 760: Total reward = -0.6000000000000003
# Episode 761: Total reward = 0.8
# Episode 762: Total reward = -1.600000000000001
# Episode 763: Total reward = 0.20000000000000007
# Episode 764: Total reward = -7.499999999999986
# Episode 765: Total reward = 1
# Episode 766: Total reward = -11.399999999999972
# Episode 767: Total reward = -1.700000000000001
# Episode 768: Total reward = -18.0
# Episode 769: Total reward = 0.6
# Episode 770: Total reward = 0.7
# Episode 771: Total reward = 1.1102230246251565e-16
# Episode 772: Total reward = -5.8999999999999915
# Episode 773: Total reward = 1
# Episode 774: Total reward = -2.1000000000000014
# Episode 775: Total reward = -4.599999999999996
# Episode 776: Total reward = -0.09999999999999987
# Episode 777: Total reward = -1.0000000000000004
# Episode 778: Total reward = 0.6
# Episode 779: Total reward = 0.7
# Episode 780: Total reward = -6.099999999999991
# Episode 781: Total reward = -7.499999999999986
# Episode 782: Total reward = 1
# Episode 783: Total reward = -6.39999999999999
# Episode 784: Total reward = -0.30000000000000004
# Episode 785: Total reward = -2.4000000000000017
# Episode 786: Total reward = -1.0000000000000004
# Episode 787: Total reward = 0.9
# Episode 788: Total reward = 0.9
# Episode 789: Total reward = 1
# Episode 790: Total reward = 0.9
# Episode 791: Total reward = 0.9
# Episode 792: Total reward = 1
# Episode 793: Total reward = 0.9
# Episode 794: Total reward = 0.9
# Episode 795: Total reward = -19.900000000000027
# Episode 796: Total reward = -4.799999999999995
# Episode 797: Total reward = 1.1102230246251565e-16
# Episode 798: Total reward = 1
# Episode 799: Total reward = 0.20000000000000007
# Episode 800: Total reward = 0.9
# Episode 801: Total reward = 0.9
# Episode 802: Total reward = -3.9999999999999982
# Episode 803: Total reward = 1
# Episode 804: Total reward = 0.9
# Episode 805: Total reward = -1.2000000000000006
# Episode 806: Total reward = 0.8
# Episode 807: Total reward = 1
# Episode 808: Total reward = 0.8
# Episode 809: Total reward = -2.600000000000002
# Episode 810: Total reward = 1
# Episode 811: Total reward = -2.0000000000000013
# Episode 812: Total reward = 0.30000000000000004
# Episode 813: Total reward = -0.7000000000000004
# Episode 814: Total reward = 0.9
# Episode 815: Total reward = 0.10000000000000009
# Episode 816: Total reward = 1
# Episode 817: Total reward = 1
# Episode 818: Total reward = 1.1102230246251565e-16
# Episode 819: Total reward = 1
# Episode 820: Total reward = 1
# Episode 821: Total reward = -25.600000000000108
# Episode 822: Total reward = -1.8000000000000012
# Episode 823: Total reward = 1
# Episode 824: Total reward = 1
# Episode 825: Total reward = 1.1102230246251565e-16
# Episode 826: Total reward = 0.6
# Episode 827: Total reward = -1.5000000000000009
# Episode 828: Total reward = 0.6
# Episode 829: Total reward = 0.5
# Episode 830: Total reward = -1.9000000000000012
# Episode 831: Total reward = -1.3000000000000007
# Episode 832: Total reward = -0.30000000000000004
# Episode 833: Total reward = -26.50000000000012
# Episode 834: Total reward = -6.799999999999988
# Episode 835: Total reward = -0.30000000000000004
# Episode 836: Total reward = 0.7
# Episode 837: Total reward = 0.5
# Episode 838: Total reward = 1
# Episode 839: Total reward = 1
# Episode 840: Total reward = -11.399999999999972
# Episode 841: Total reward = 0.30000000000000004
# Episode 842: Total reward = 1
# Episode 843: Total reward = 0.6
# Episode 844: Total reward = 1
# Episode 845: Total reward = 0.7
# Episode 846: Total reward = 1
# Episode 847: Total reward = 0.30000000000000004
# Episode 848: Total reward = -1.4000000000000008
# Episode 849: Total reward = 0.20000000000000007
# Episode 850: Total reward = -5.799999999999992
# Episode 851: Total reward = 0.5
# Episode 852: Total reward = -1.0000000000000004
# Episode 853: Total reward = -0.19999999999999996
# Episode 854: Total reward = -0.7000000000000004
# Episode 855: Total reward = -3.5999999999999996
# Episode 856: Total reward = 0.6
# Episode 857: Total reward = 0.9
# Episode 858: Total reward = 0.8
# Episode 859: Total reward = -0.30000000000000004
# Episode 860: Total reward = 0.10000000000000009
# Episode 861: Total reward = -0.8000000000000005
# Episode 862: Total reward = -1.8000000000000012
# Episode 863: Total reward = -7.499999999999986
# Episode 864: Total reward = -0.30000000000000004
# Episode 865: Total reward = 0.4
# Episode 866: Total reward = 0.5
# Episode 867: Total reward = 1
# Episode 868: Total reward = 0.6
# Episode 869: Total reward = 0.10000000000000009
# Episode 870: Total reward = -2.800000000000002
# Episode 871: Total reward = 0.30000000000000004
# Episode 872: Total reward = -4.1999999999999975
# Episode 873: Total reward = -0.7000000000000004
# Episode 874: Total reward = 0.10000000000000009
# Episode 875: Total reward = -0.8000000000000005
# Episode 876: Total reward = 0.5
# Episode 877: Total reward = 0.4
# Episode 878: Total reward = 1.1102230246251565e-16
# Episode 879: Total reward = 0.5
# Episode 880: Total reward = 0.30000000000000004
# Episode 881: Total reward = 0.8
# Episode 882: Total reward = 1
# Episode 883: Total reward = -2.1000000000000014
# Episode 884: Total reward = 0.7
# Episode 885: Total reward = -2.4000000000000017
# Episode 886: Total reward = -0.7000000000000004
# Episode 887: Total reward = 1
# Episode 888: Total reward = 0.4
# Episode 889: Total reward = -12.599999999999968
# Episode 890: Total reward = 0.9
# Episode 891: Total reward = -1.700000000000001
# Episode 892: Total reward = -2.0000000000000013
# Episode 893: Total reward = -0.30000000000000004
# Episode 894: Total reward = 1
# Episode 895: Total reward = 0.9
# Episode 896: Total reward = -1.1000000000000005
# Episode 897: Total reward = -1.0000000000000004
# Episode 898: Total reward = -6.499999999999989
# Episode 899: Total reward = -8.699999999999982
# Episode 900: Total reward = 0.5
# Episode 901: Total reward = 0.8
# Episode 902: Total reward = -13.899999999999963
# Episode 903: Total reward = 1
# Episode 904: Total reward = -2.900000000000002
# Episode 905: Total reward = -0.30000000000000004
# Episode 906: Total reward = -0.30000000000000004
# Episode 907: Total reward = -3.200000000000001
# Episode 908: Total reward = -6.29999999999999
# Episode 909: Total reward = 0.30000000000000004
# Episode 910: Total reward = -0.8000000000000005
# Episode 911: Total reward = -2.3000000000000016
# Episode 912: Total reward = 0.20000000000000007
# Episode 913: Total reward = 1
# Episode 914: Total reward = -0.30000000000000004
# Episode 915: Total reward = 1.1102230246251565e-16
# Episode 916: Total reward = -3.3000000000000007
# Episode 917: Total reward = -0.7000000000000004
# Episode 918: Total reward = 0.30000000000000004
# Episode 919: Total reward = 0.20000000000000007
# Episode 920: Total reward = 0.5
# Episode 921: Total reward = -0.9000000000000006
# Episode 922: Total reward = 0.9
# Episode 923: Total reward = -3.8999999999999986
# Episode 924: Total reward = -1.5000000000000009
# Episode 925: Total reward = 0.9
# Episode 926: Total reward = -4.4999999999999964
# Episode 927: Total reward = -0.6000000000000003
# Episode 928: Total reward = -2.600000000000002
# Episode 929: Total reward = 0.9
# Episode 930: Total reward = 1.1102230246251565e-16
# Episode 931: Total reward = -1.5000000000000009
# Episode 932: Total reward = -0.19999999999999996
# Episode 933: Total reward = -1.3000000000000007
# Episode 934: Total reward = -5.999999999999991
# Episode 935: Total reward = -7.099999999999987
# Episode 936: Total reward = -3.5999999999999996
# Episode 937: Total reward = -12.09999999999997
# Episode 938: Total reward = -0.40000000000000013
# Episode 939: Total reward = 1
# Episode 940: Total reward = -0.40000000000000013
# Episode 941: Total reward = 0.5
# Episode 942: Total reward = -15.799999999999969
# Episode 943: Total reward = -21.40000000000005
# Episode 944: Total reward = 0.30000000000000004
# Episode 945: Total reward = -1.2000000000000006
# Episode 946: Total reward = -1.5000000000000009
# Episode 947: Total reward = -14.69999999999996
# Episode 948: Total reward = 0.6
# Episode 949: Total reward = -2.5000000000000018
# Episode 950: Total reward = -0.19999999999999996
# Episode 951: Total reward = 0.8
# Episode 952: Total reward = -5.299999999999994
# Episode 953: Total reward = -1.2000000000000006
# Episode 954: Total reward = 0.5
# Episode 955: Total reward = -10.099999999999977
# Episode 956: Total reward = -2.800000000000002
# Episode 957: Total reward = 1
# Episode 958: Total reward = 0.10000000000000009
# Episode 959: Total reward = 0.10000000000000009
# Episode 960: Total reward = -3.4000000000000004
# Episode 961: Total reward = -1.1000000000000005
# Episode 962: Total reward = 0.30000000000000004
# Episode 963: Total reward = -1.700000000000001
# Episode 964: Total reward = -1.2000000000000006
# Episode 965: Total reward = -39.3000000000003
# Episode 966: Total reward = -8.299999999999983
# Episode 967: Total reward = -7.599999999999985
# Episode 968: Total reward = -4.099999999999998
# Episode 969: Total reward = 0.6
# Episode 970: Total reward = -2.3000000000000016
# Episode 971: Total reward = 0.8
# Episode 972: Total reward = -0.30000000000000004
# Episode 973: Total reward = -1.1000000000000005
# Episode 974: Total reward = 1
# Episode 975: Total reward = -1.600000000000001
# Episode 976: Total reward = 0.9
# Episode 977: Total reward = -2.1000000000000014
# Episode 978: Total reward = -0.5000000000000002
# Episode 979: Total reward = -4.699999999999996
# Episode 980: Total reward = 0.5
# Episode 981: Total reward = 1.1102230246251565e-16
# Episode 982: Total reward = 1
# Episode 983: Total reward = -3.799999999999999
# Episode 984: Total reward = -2.1000000000000014
# Episode 985: Total reward = 1.1102230246251565e-16
# Episode 986: Total reward = 1.1102230246251565e-16
# Episode 987: Total reward = 0.8
# Episode 988: Total reward = -1.1000000000000005
# Episode 989: Total reward = -2.900000000000002
# Episode 990: Total reward = -0.09999999999999987
# Episode 991: Total reward = -1.9000000000000012
# Episode 992: Total reward = 0.20000000000000007
# Episode 993: Total reward = -6.29999999999999
# Episode 994: Total reward = -0.5000000000000002
# Episode 995: Total reward = 0.4
# Episode 996: Total reward = -9.999999999999977
# Episode 997: Total reward = -6.799999999999988
# Episode 998: Total reward = 0.4
# Episode 999: Total reward = -0.19999999999999996
